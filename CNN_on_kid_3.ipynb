# %% [markdown]
# <a href="https://colab.research.google.com/github/rish4/CNN-on-KID-new/blob/master/CNN_on_kid_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing necessary libraries**

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %% [markdown]
# **Generate batches of image data with data augmentation**

# %%
## Set file paths to image files
#project_path = "/Users/hellojenny/Metis/Metis-Bootcamp/Projects/Project 5 - Image Prediction using CNN"
train_path = "/content/drive/My Drive/KID dataset - Copy/Training set"
#val_path = project_path + "/chest_xray/val/"
test_path = "/content/drive/My Drive/KID dataset - Copy/Test set"

## Set up hyperparameters that will be used later
hyper_dimension = 64
hyper_batch_size = 32
hyper_epochs = 100
hyper_channels = 3
hyper_mode = 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
#val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 


train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
'''val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)'''
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()
# Out:
# Found 685 images belonging to 2 classes.
# Found 171 images belonging to 2 classes.

# %% [markdown]
# **Train the model**

# %%
cnn = Sequential()
cnn.add(InputLayer(input_shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit_generator(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 80, 
                              validation_data = test_generator,
                              validation_steps = len(test_generator), 
                              verbose=2)
# Out:
# Epoch 1/80
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 9 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 6 could not be retrieved. It could be because a worker has died.
#   UserWarning)
#  - 525s - loss: 0.6059 - auc_2: 0.7317 - val_loss: 0.3189 - val_auc_2: 0.7596
# Epoch 2/80
#  - 7s - loss: 0.4659 - auc_2: 0.8196 - val_loss: 0.2336 - val_auc_2: 0.8641
# Epoch 3/80
#  - 7s - loss: 0.4258 - auc_2: 0.8783 - val_loss: 0.1833 - val_auc_2: 0.9166
# Epoch 4/80
#  - 7s - loss: 0.3498 - auc_2: 0.9359 - val_loss: 0.0814 - val_auc_2: 0.9390
# Epoch 5/80
#  - 7s - loss: 0.3166 - auc_2: 0.9395 - val_loss: 0.0620 - val_auc_2: 0.9479
# Epoch 6/80
#  - 7s - loss: 0.2860 - auc_2: 0.9485 - val_loss: 0.1348 - val_auc_2: 0.9466
# Epoch 7/80
#  - 7s - loss: 0.3002 - auc_2: 0.9452 - val_loss: 0.1023 - val_auc_2: 0.9596
# Epoch 8/80
#  - 7s - loss: 0.2405 - auc_2: 0.9635 - val_loss: 0.3444 - val_auc_2: 0.9550
# Epoch 9/80
#  - 7s - loss: 0.2701 - auc_2: 0.9548 - val_loss: 0.0227 - val_auc_2: 0.9586
# Epoch 10/80
#  - 7s - loss: 0.2704 - auc_2: 0.9556 - val_loss: 0.0195 - val_auc_2: 0.9445
# Epoch 11/80
#  - 7s - loss: 0.2412 - auc_2: 0.9642 - val_loss: 0.0520 - val_auc_2: 0.9556
# Epoch 12/80
#  - 7s - loss: 0.2206 - auc_2: 0.9692 - val_loss: 0.1013 - val_auc_2: 0.9624
# Epoch 13/80
#  - 7s - loss: 0.2378 - auc_2: 0.9664 - val_loss: 0.0452 - val_auc_2: 0.9538
# Epoch 14/80
#  - 7s - loss: 0.2447 - auc_2: 0.9639 - val_loss: 0.0166 - val_auc_2: 0.9340
# Epoch 15/80
#  - 7s - loss: 0.2326 - auc_2: 0.9683 - val_loss: 0.0281 - val_auc_2: 0.9624
# Epoch 16/80
#  - 7s - loss: 0.2182 - auc_2: 0.9699 - val_loss: 0.0336 - val_auc_2: 0.9464
# Epoch 17/80
#  - 7s - loss: 0.2123 - auc_2: 0.9732 - val_loss: 0.0846 - val_auc_2: 0.9610
# Epoch 18/80
#  - 7s - loss: 0.2436 - auc_2: 0.9633 - val_loss: 0.0148 - val_auc_2: 0.9532
# Epoch 19/80
#  - 7s - loss: 0.2375 - auc_2: 0.9646 - val_loss: 0.0700 - val_auc_2: 0.9571
# Epoch 20/80
#  - 7s - loss: 0.2315 - auc_2: 0.9670 - val_loss: 0.1224 - val_auc_2: 0.9529
# Epoch 21/80
#  - 7s - loss: 0.2004 - auc_2: 0.9757 - val_loss: 0.0193 - val_auc_2: 0.9376
# Epoch 22/80
#  - 7s - loss: 0.2128 - auc_2: 0.9716 - val_loss: 0.2211 - val_auc_2: 0.9505
# Epoch 23/80
#  - 7s - loss: 0.2002 - auc_2: 0.9743 - val_loss: 0.0291 - val_auc_2: 0.9542
# Epoch 24/80
#  - 7s - loss: 0.1691 - auc_2: 0.9819 - val_loss: 0.0238 - val_auc_2: 0.9400
# Epoch 25/80
#  - 7s - loss: 0.1900 - auc_2: 0.9772 - val_loss: 0.1255 - val_auc_2: 0.9527
# Epoch 26/80
#  - 7s - loss: 0.2047 - auc_2: 0.9741 - val_loss: 0.0913 - val_auc_2: 0.9325
# Epoch 27/80
#  - 7s - loss: 0.1897 - auc_2: 0.9781 - val_loss: 0.2358 - val_auc_2: 0.9607
# Epoch 28/80
#  - 7s - loss: 0.1728 - auc_2: 0.9810 - val_loss: 0.0926 - val_auc_2: 0.9571
# Epoch 29/80
#  - 7s - loss: 0.1921 - auc_2: 0.9777 - val_loss: 0.1574 - val_auc_2: 0.9652
# Epoch 30/80
#  - 7s - loss: 0.1662 - auc_2: 0.9842 - val_loss: 0.1157 - val_auc_2: 0.9580
# Epoch 31/80
#  - 7s - loss: 0.1581 - auc_2: 0.9844 - val_loss: 0.0721 - val_auc_2: 0.9599
# Epoch 32/80
#  - 7s - loss: 0.1423 - auc_2: 0.9873 - val_loss: 0.0583 - val_auc_2: 0.9622
# Epoch 33/80
#  - 7s - loss: 0.1421 - auc_2: 0.9882 - val_loss: 0.0504 - val_auc_2: 0.9508
# Epoch 34/80
#  - 7s - loss: 0.1378 - auc_2: 0.9884 - val_loss: 0.0225 - val_auc_2: 0.9580
# Epoch 35/80
#  - 7s - loss: 0.2030 - auc_2: 0.9741 - val_loss: 0.0475 - val_auc_2: 0.9525
# Epoch 36/80
#  - 7s - loss: 0.1573 - auc_2: 0.9843 - val_loss: 0.1190 - val_auc_2: 0.9633
# Epoch 37/80
#  - 7s - loss: 0.1438 - auc_2: 0.9876 - val_loss: 0.0395 - val_auc_2: 0.9526
# Epoch 38/80
#  - 7s - loss: 0.1241 - auc_2: 0.9899 - val_loss: 0.0562 - val_auc_2: 0.9556
# Epoch 39/80
#  - 10s - loss: 0.1369 - auc_2: 0.9884 - val_loss: 0.0220 - val_auc_2: 0.9588
# Epoch 40/80
#  - 7s - loss: 0.1263 - auc_2: 0.9908 - val_loss: 0.0201 - val_auc_2: 0.9487
# Epoch 41/80
#  - 7s - loss: 0.1226 - auc_2: 0.9910 - val_loss: 0.0146 - val_auc_2: 0.9573
# Epoch 42/80
#  - 7s - loss: 0.1578 - auc_2: 0.9840 - val_loss: 0.0218 - val_auc_2: 0.9204
# Epoch 43/80
#  - 7s - loss: 0.1308 - auc_2: 0.9894 - val_loss: 0.0125 - val_auc_2: 0.9578
# Epoch 44/80
#  - 7s - loss: 0.1174 - auc_2: 0.9904 - val_loss: 0.1101 - val_auc_2: 0.9591
# Epoch 45/80
#  - 7s - loss: 0.1427 - auc_2: 0.9865 - val_loss: 0.0058 - val_auc_2: 0.9580
# Epoch 46/80
#  - 7s - loss: 0.1456 - auc_2: 0.9861 - val_loss: 0.0078 - val_auc_2: 0.9512
# Epoch 47/80
#  - 7s - loss: 0.1529 - auc_2: 0.9854 - val_loss: 0.1313 - val_auc_2: 0.9584
# Epoch 48/80
#  - 7s - loss: 0.1559 - auc_2: 0.9841 - val_loss: 0.0198 - val_auc_2: 0.9581
# Epoch 49/80
#  - 7s - loss: 0.1204 - auc_2: 0.9918 - val_loss: 0.0315 - val_auc_2: 0.9457
# Epoch 50/80
#  - 7s - loss: 0.1226 - auc_2: 0.9917 - val_loss: 0.0087 - val_auc_2: 0.9520
# Epoch 51/80
#  - 7s - loss: 0.1129 - auc_2: 0.9912 - val_loss: 0.0185 - val_auc_2: 0.9582
# Epoch 52/80
#  - 7s - loss: 0.1205 - auc_2: 0.9895 - val_loss: 0.0090 - val_auc_2: 0.9592
# Epoch 53/80
#  - 7s - loss: 0.0872 - auc_2: 0.9957 - val_loss: 0.0113 - val_auc_2: 0.9502
# Epoch 54/80
#  - 7s - loss: 0.0870 - auc_2: 0.9953 - val_loss: 0.0266 - val_auc_2: 0.9543
# Epoch 55/80
#  - 7s - loss: 0.0917 - auc_2: 0.9949 - val_loss: 4.6523e-04 - val_auc_2: 0.9320
# Epoch 56/80
#  - 7s - loss: 0.1128 - auc_2: 0.9915 - val_loss: 0.1100 - val_auc_2: 0.9637
# Epoch 57/80
#  - 7s - loss: 0.1068 - auc_2: 0.9916 - val_loss: 0.0068 - val_auc_2: 0.9514
# Epoch 58/80
#  - 7s - loss: 0.0798 - auc_2: 0.9963 - val_loss: 4.0972e-04 - val_auc_2: 0.9270
# Epoch 59/80
#  - 7s - loss: 0.0934 - auc_2: 0.9947 - val_loss: 0.0173 - val_auc_2: 0.9623
# Epoch 60/80
#  - 7s - loss: 0.0767 - auc_2: 0.9967 - val_loss: 0.0033 - val_auc_2: 0.9580
# Epoch 61/80
#  - 7s - loss: 0.0622 - auc_2: 0.9978 - val_loss: 0.0033 - val_auc_2: 0.9560
# Epoch 62/80
#  - 7s - loss: 0.0507 - auc_2: 0.9988 - val_loss: 0.0015 - val_auc_2: 0.9447
# Epoch 63/80
#  - 7s - loss: 0.0656 - auc_2: 0.9973 - val_loss: 0.0367 - val_auc_2: 0.9511
# Epoch 64/80
#  - 7s - loss: 0.0977 - auc_2: 0.9941 - val_loss: 0.0081 - val_auc_2: 0.9475
# Epoch 65/80
#  - 7s - loss: 0.0587 - auc_2: 0.9983 - val_loss: 7.2079e-04 - val_auc_2: 0.9540
# Epoch 66/80
#  - 7s - loss: 0.0786 - auc_2: 0.9961 - val_loss: 0.1342 - val_auc_2: 0.9433
# Epoch 67/80
#  - 7s - loss: 0.0849 - auc_2: 0.9954 - val_loss: 0.0319 - val_auc_2: 0.9688
# Epoch 68/80
#  - 7s - loss: 0.0925 - auc_2: 0.9945 - val_loss: 9.9821e-04 - val_auc_2: 0.9348
# Epoch 69/80
#  - 7s - loss: 0.0889 - auc_2: 0.9944 - val_loss: 0.0037 - val_auc_2: 0.9540
# Epoch 70/80
#  - 7s - loss: 0.0890 - auc_2: 0.9938 - val_loss: 0.0122 - val_auc_2: 0.9510
# Epoch 71/80
#  - 7s - loss: 0.0613 - auc_2: 0.9967 - val_loss: 0.0090 - val_auc_2: 0.9672
# Epoch 72/80
#  - 7s - loss: 0.0529 - auc_2: 0.9982 - val_loss: 6.0914e-04 - val_auc_2: 0.9272
# Epoch 73/80
#  - 7s - loss: 0.0635 - auc_2: 0.9976 - val_loss: 0.1263 - val_auc_2: 0.9523
# Epoch 74/80
#  - 7s - loss: 0.0654 - auc_2: 0.9979 - val_loss: 0.0022 - val_auc_2: 0.9510
# Epoch 75/80
#  - 7s - loss: 0.0796 - auc_2: 0.9961 - val_loss: 0.0046 - val_auc_2: 0.9546
# Epoch 76/80
#  - 7s - loss: 0.0832 - auc_2: 0.9945 - val_loss: 0.0161 - val_auc_2: 0.9310
# Epoch 77/80
#  - 7s - loss: 0.1007 - auc_2: 0.9940 - val_loss: 8.9229e-04 - val_auc_2: 0.9496
# Epoch 78/80
#  - 7s - loss: 0.0675 - auc_2: 0.9970 - val_loss: 0.0061 - val_auc_2: 0.9630
# Epoch 79/80
#  - 7s - loss: 0.0468 - auc_2: 0.9991 - val_loss: 0.0511 - val_auc_2: 0.9613
# Epoch 80/80
#  - 7s - loss: 0.0482 - auc_2: 0.9973 - val_loss: 0.0153 - val_auc_2: 0.9547

# %% [markdown]
# **Create a function that outputs metrics and charts**

# %%
def create_charts(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict_generator(test_generator, steps = len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts(cnn, cnn_model)
# Out:
# [Summary Statistics]
# Accuracy = 91.81% | Precision = 90.36% | Recall = 92.59% | Specificity = 91.11% | F1 Score = 91.46%

# %% [markdown]
# ---
#
# **Test the model for a new image**
#
# ---

# %%
import numpy as np
from keras.preprocessing import image
test_image= image.load_img('/content/drive/My Drive/KID dataset - Copy/Test set/Unhealthy/angioectasia-P0-6.png', target_size=(64,64))
test_image=image.img_to_array(test_image)
test_image= np.expand_dims(test_image, axis=0)
result=cnn.predict(test_image)
print(result)
if result[0][0] == 1:
  prediction= 'Abnormal'
else:
  prediction= 'Normal'
# Out:
# [[1.]]

# %%
print(prediction)
# Out:
# Abnormal
