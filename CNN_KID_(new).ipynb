# %% [markdown]
# <a href="https://colab.research.google.com/github/rish4/CNN-on-KID-new/blob/master/CNN_KID_(new).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing necessary libraries**

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %% [markdown]
# **Set random seed**

# %%
# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# 5. For layers that introduce randomness like dropout, make sure to set seed values 
#model.add(Dropout(0.25, seed=seed_value))

#6 Configure a new global `tensorflow` session
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
#K.set_session(sess)

# %% [markdown]
# **Generate batches of image data with data augmentation**

# %%
## Set file paths to image files
#project_path = "/Users/hellojenny/Metis/Metis-Bootcamp/Projects/Project 5 - Image Prediction using CNN"
train_path = "/content/drive/My Drive/KID dataset - Copy/Training set"
#val_path = project_path + "/chest_xray/val/"
test_path = "/content/drive/My Drive/KID dataset - Copy/Test set"

## Set up hyperparameters that will be used later
hyper_dimension = 64
hyper_batch_size = 32
hyper_epochs = 100
hyper_channels = 3
hyper_mode = 'grayscale'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
#val_datagen = ImageDataGenerator(rescale=1.0/255.0) 
test_datagen = ImageDataGenerator(rescale=1.0/255.0) 


train_generator = train_datagen.flow_from_directory(directory = train_path, 
                                                    target_size = (hyper_dimension, hyper_dimension),
                                                    batch_size = hyper_batch_size, 
                                                    color_mode = hyper_mode,
                                                    class_mode = 'binary', 
                                                    seed = 42)
'''val_generator = val_datagen.flow_from_directory(directory = val_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)'''
test_generator = test_datagen.flow_from_directory(directory = test_path, 
                                                 target_size = (hyper_dimension, hyper_dimension),
                                                 batch_size = hyper_batch_size, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode,
                                                 shuffle=False,
                                                 seed = 42)

test_generator.reset()
# Out:
# Found 685 images belonging to 2 classes.
# Found 171 images belonging to 2 classes.

# %% [markdown]
# **Train the model**

# %%
cnn = Sequential()
cnn.add(InputLayer(input_shape=(hyper_dimension, hyper_dimension, hyper_channels)))

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())

cnn.add(Dense(activation='relu', units=128))
cnn.add(Dense(activation='sigmoid', units=1))

cnn.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=[AUC()])
cnn_model = cnn.fit_generator(train_generator, 
                              steps_per_epoch = len(train_generator), 
                              epochs = 200, 
                              validation_data = test_generator,
                              validation_steps = len(test_generator), 
                              verbose=2)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 2 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 15 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 9 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 12 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 16 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 19 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 6 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 13 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 18 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 14 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 10 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 1 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 11 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 4 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 17 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 7 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 8 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 0 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 3 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 20 could not be retrieved. It could be because a worker has died.
#   UserWarning)
#  - 691s - loss: 0.6992 - auc_1: 0.4984 - val_loss: 0.6932 - val_auc_1: 0.5940
# Epoch 2/200
#  - 4s - loss: 0.6913 - auc_1: 0.5424 - val_loss: 0.7318 - val_auc_1: 0.5835
# Epoch 3/200
#  - 4s - loss: 0.6916 - auc_1: 0.5177 - val_loss: 0.7772 - val_auc_1: 0.5807
# Epoch 4/200
#  - 4s - loss: 0.6849 - auc_1: 0.5959 - val_loss: 0.6764 - val_auc_1: 0.6582
# Epoch 5/200
#  - 4s - loss: 0.6771 - auc_1: 0.6267 - val_loss: 0.9296 - val_auc_1: 0.6558
# Epoch 6/200
#  - 4s - loss: 0.6697 - auc_1: 0.6225 - val_loss: 0.8691 - val_auc_1: 0.6480
# Epoch 7/200
#  - 4s - loss: 0.6585 - auc_1: 0.6439 - val_loss: 0.5922 - val_auc_1: 0.6857
# Epoch 8/200
#  - 4s - loss: 0.6346 - auc_1: 0.6962 - val_loss: 0.7203 - val_auc_1: 0.6963
# Epoch 9/200
#  - 4s - loss: 0.6242 - auc_1: 0.7056 - val_loss: 0.5170 - val_auc_1: 0.7161
# Epoch 10/200
#  - 4s - loss: 0.5902 - auc_1: 0.7575 - val_loss: 0.6105 - val_auc_1: 0.7144
# Epoch 11/200
#  - 4s - loss: 0.5811 - auc_1: 0.7629 - val_loss: 0.9419 - val_auc_1: 0.7248
# Epoch 12/200
#  - 4s - loss: 0.6094 - auc_1: 0.7280 - val_loss: 0.5398 - val_auc_1: 0.7329
# Epoch 13/200
#  - 4s - loss: 0.5777 - auc_1: 0.7782 - val_loss: 0.4461 - val_auc_1: 0.7541
# Epoch 14/200
#  - 4s - loss: 0.5533 - auc_1: 0.7976 - val_loss: 0.8992 - val_auc_1: 0.7570
# Epoch 15/200
#  - 4s - loss: 0.5730 - auc_1: 0.7668 - val_loss: 0.6559 - val_auc_1: 0.7507
# Epoch 16/200
#  - 4s - loss: 0.5306 - auc_1: 0.8170 - val_loss: 0.2914 - val_auc_1: 0.7687
# Epoch 17/200
#  - 4s - loss: 0.5262 - auc_1: 0.8077 - val_loss: 0.3235 - val_auc_1: 0.7603
# Epoch 18/200
#  - 4s - loss: 0.5137 - auc_1: 0.8178 - val_loss: 0.4691 - val_auc_1: 0.7816
# Epoch 19/200
#  - 4s - loss: 0.4895 - auc_1: 0.8385 - val_loss: 0.3402 - val_auc_1: 0.7622
# Epoch 20/200
#  - 4s - loss: 0.5056 - auc_1: 0.8288 - val_loss: 0.4719 - val_auc_1: 0.7871
# Epoch 21/200
#  - 4s - loss: 0.4968 - auc_1: 0.8376 - val_loss: 0.3458 - val_auc_1: 0.7816
# Epoch 22/200
#  - 4s - loss: 0.4953 - auc_1: 0.8416 - val_loss: 0.3375 - val_auc_1: 0.7877
# Epoch 23/200
#  - 4s - loss: 0.5034 - auc_1: 0.8360 - val_loss: 0.3862 - val_auc_1: 0.7825
# Epoch 24/200
#  - 4s - loss: 0.5139 - auc_1: 0.8300 - val_loss: 0.4229 - val_auc_1: 0.7890
# Epoch 25/200
#  - 4s - loss: 0.4596 - auc_1: 0.8581 - val_loss: 0.3656 - val_auc_1: 0.7953
# Epoch 26/200
#  - 4s - loss: 0.4515 - auc_1: 0.8705 - val_loss: 0.2647 - val_auc_1: 0.7960
# Epoch 27/200
#  - 4s - loss: 0.4355 - auc_1: 0.8777 - val_loss: 0.3562 - val_auc_1: 0.7996
# Epoch 28/200
#  - 5s - loss: 0.4318 - auc_1: 0.8804 - val_loss: 0.2999 - val_auc_1: 0.8072
# Epoch 29/200
#  - 4s - loss: 0.4364 - auc_1: 0.8741 - val_loss: 0.4669 - val_auc_1: 0.8023
# Epoch 30/200
#  - 4s - loss: 0.4350 - auc_1: 0.8789 - val_loss: 0.5476 - val_auc_1: 0.7910
# Epoch 31/200
#  - 4s - loss: 0.4085 - auc_1: 0.8941 - val_loss: 0.1795 - val_auc_1: 0.8119
# Epoch 32/200
#  - 4s - loss: 0.4335 - auc_1: 0.8798 - val_loss: 0.3667 - val_auc_1: 0.8106
# Epoch 33/200
#  - 5s - loss: 0.3894 - auc_1: 0.9076 - val_loss: 0.2030 - val_auc_1: 0.8127
# Epoch 34/200
#  - 4s - loss: 0.4040 - auc_1: 0.8991 - val_loss: 0.4852 - val_auc_1: 0.8103
# Epoch 35/200
#  - 4s - loss: 0.3969 - auc_1: 0.8980 - val_loss: 0.5723 - val_auc_1: 0.8052
# Epoch 36/200
#  - 4s - loss: 0.4072 - auc_1: 0.8978 - val_loss: 0.3387 - val_auc_1: 0.8060
# Epoch 37/200
#  - 4s - loss: 0.3793 - auc_1: 0.9124 - val_loss: 0.3852 - val_auc_1: 0.8066
# Epoch 38/200
#  - 4s - loss: 0.3790 - auc_1: 0.9064 - val_loss: 0.3670 - val_auc_1: 0.8109
# Epoch 39/200
#  - 4s - loss: 0.3632 - auc_1: 0.9209 - val_loss: 0.5133 - val_auc_1: 0.8049
# Epoch 40/200
#  - 5s - loss: 0.3361 - auc_1: 0.9327 - val_loss: 0.3198 - val_auc_1: 0.8097
# Epoch 41/200
#  - 5s - loss: 0.3420 - auc_1: 0.9278 - val_loss: 0.2091 - val_auc_1: 0.8118
# Epoch 42/200
#  - 5s - loss: 0.3406 - auc_1: 0.9274 - val_loss: 0.5185 - val_auc_1: 0.8105
# Epoch 43/200
#  - 4s - loss: 0.3353 - auc_1: 0.9319 - val_loss: 0.1953 - val_auc_1: 0.8160
# Epoch 44/200
#  - 4s - loss: 0.3365 - auc_1: 0.9279 - val_loss: 0.5554 - val_auc_1: 0.8193
# Epoch 45/200
#  - 4s - loss: 0.3249 - auc_1: 0.9358 - val_loss: 0.3286 - val_auc_1: 0.8176
# Epoch 46/200
#  - 5s - loss: 0.3057 - auc_1: 0.9433 - val_loss: 0.8072 - val_auc_1: 0.8169
# Epoch 47/200
#  - 5s - loss: 0.3121 - auc_1: 0.9403 - val_loss: 0.8109 - val_auc_1: 0.8117
# Epoch 48/200
#  - 4s - loss: 0.3040 - auc_1: 0.9428 - val_loss: 0.5445 - val_auc_1: 0.8193
# Epoch 49/200
#  - 5s - loss: 0.2807 - auc_1: 0.9527 - val_loss: 0.5927 - val_auc_1: 0.8171
# Epoch 50/200
#  - 5s - loss: 0.3180 - auc_1: 0.9380 - val_loss: 0.6452 - val_auc_1: 0.7854
# Epoch 51/200
#  - 4s - loss: 0.2998 - auc_1: 0.9446 - val_loss: 0.4442 - val_auc_1: 0.8097
# Epoch 52/200
#  - 4s - loss: 0.2655 - auc_1: 0.9587 - val_loss: 0.3838 - val_auc_1: 0.8039
# Epoch 53/200
#  - 4s - loss: 0.2628 - auc_1: 0.9591 - val_loss: 0.4315 - val_auc_1: 0.8121
# Epoch 54/200
#  - 4s - loss: 0.2779 - auc_1: 0.9510 - val_loss: 0.5270 - val_auc_1: 0.8069
# Epoch 55/200
#  - 4s - loss: 0.2586 - auc_1: 0.9628 - val_loss: 0.2911 - val_auc_1: 0.7997
# Epoch 56/200
#  - 4s - loss: 0.2513 - auc_1: 0.9625 - val_loss: 0.3140 - val_auc_1: 0.8058
# Epoch 57/200
#  - 4s - loss: 0.2472 - auc_1: 0.9619 - val_loss: 0.6457 - val_auc_1: 0.8152
# Epoch 58/200
#  - 4s - loss: 0.2501 - auc_1: 0.9605 - val_loss: 0.8559 - val_auc_1: 0.8082
# Epoch 59/200
#  - 4s - loss: 0.3187 - auc_1: 0.9404 - val_loss: 0.6929 - val_auc_1: 0.8031
# Epoch 60/200
#  - 4s - loss: 0.2544 - auc_1: 0.9630 - val_loss: 0.7215 - val_auc_1: 0.7965
# Epoch 61/200
#  - 4s - loss: 0.2293 - auc_1: 0.9687 - val_loss: 0.2345 - val_auc_1: 0.7981
# Epoch 62/200
#  - 4s - loss: 0.2368 - auc_1: 0.9651 - val_loss: 0.6332 - val_auc_1: 0.8100
# Epoch 63/200
#  - 4s - loss: 0.2138 - auc_1: 0.9750 - val_loss: 0.2783 - val_auc_1: 0.7995
# Epoch 64/200
#  - 4s - loss: 0.1860 - auc_1: 0.9804 - val_loss: 0.6218 - val_auc_1: 0.7956
# Epoch 65/200
#  - 4s - loss: 0.1887 - auc_1: 0.9793 - val_loss: 0.5378 - val_auc_1: 0.7977
# Epoch 66/200
#  - 4s - loss: 0.1861 - auc_1: 0.9811 - val_loss: 0.4090 - val_auc_1: 0.8001
# Epoch 67/200
#  - 4s - loss: 0.1763 - auc_1: 0.9829 - val_loss: 0.2186 - val_auc_1: 0.8062
# Epoch 68/200
#  - 4s - loss: 0.2084 - auc_1: 0.9755 - val_loss: 0.6230 - val_auc_1: 0.8053
# Epoch 69/200
#  - 4s - loss: 0.2415 - auc_1: 0.9629 - val_loss: 0.2156 - val_auc_1: 0.7841
# Epoch 70/200
#  - 4s - loss: 0.2229 - auc_1: 0.9698 - val_loss: 0.6237 - val_auc_1: 0.7918
# Epoch 71/200
#  - 4s - loss: 0.2112 - auc_1: 0.9730 - val_loss: 0.5693 - val_auc_1: 0.8037
# Epoch 72/200
#  - 4s - loss: 0.2030 - auc_1: 0.9761 - val_loss: 0.8213 - val_auc_1: 0.7970
# Epoch 73/200
#  - 4s - loss: 0.1628 - auc_1: 0.9855 - val_loss: 0.3301 - val_auc_1: 0.8031
# Epoch 74/200
#  - 4s - loss: 0.1538 - auc_1: 0.9869 - val_loss: 0.7815 - val_auc_1: 0.8089
# Epoch 75/200
#  - 4s - loss: 0.1746 - auc_1: 0.9820 - val_loss: 0.4618 - val_auc_1: 0.8104
# Epoch 76/200
#  - 4s - loss: 0.1635 - auc_1: 0.9874 - val_loss: 1.0777 - val_auc_1: 0.7975
# Epoch 77/200
#  - 4s - loss: 0.1645 - auc_1: 0.9845 - val_loss: 0.5143 - val_auc_1: 0.7984
# Epoch 78/200
#  - 4s - loss: 0.1729 - auc_1: 0.9830 - val_loss: 0.9535 - val_auc_1: 0.7984
# Epoch 79/200
#  - 4s - loss: 0.1641 - auc_1: 0.9858 - val_loss: 1.0930 - val_auc_1: 0.8034
# Epoch 80/200
#  - 5s - loss: 0.1507 - auc_1: 0.9870 - val_loss: 0.8178 - val_auc_1: 0.8062
# Epoch 81/200
#  - 5s - loss: 0.1947 - auc_1: 0.9756 - val_loss: 0.2209 - val_auc_1: 0.8003
# Epoch 82/200
#  - 4s - loss: 0.1544 - auc_1: 0.9872 - val_loss: 0.5139 - val_auc_1: 0.8013
# Epoch 83/200
#  - 4s - loss: 0.1166 - auc_1: 0.9948 - val_loss: 0.6429 - val_auc_1: 0.8150
# Epoch 84/200
#  - 5s - loss: 0.1290 - auc_1: 0.9903 - val_loss: 0.6044 - val_auc_1: 0.8163
# Epoch 85/200
#  - 4s - loss: 0.1218 - auc_1: 0.9911 - val_loss: 0.4718 - val_auc_1: 0.8084
# Epoch 86/200
#  - 4s - loss: 0.1445 - auc_1: 0.9885 - val_loss: 0.1537 - val_auc_1: 0.8106
# Epoch 87/200
#  - 4s - loss: 0.1403 - auc_1: 0.9882 - val_loss: 0.4470 - val_auc_1: 0.8056
# Epoch 88/200
#  - 5s - loss: 0.1300 - auc_1: 0.9900 - val_loss: 1.1655 - val_auc_1: 0.8091
# Epoch 89/200
#  - 4s - loss: 0.1182 - auc_1: 0.9928 - val_loss: 1.5450 - val_auc_1: 0.7973
# Epoch 90/200
#  - 4s - loss: 0.0943 - auc_1: 0.9961 - val_loss: 0.9929 - val_auc_1: 0.8067
# Epoch 91/200
#  - 4s - loss: 0.0940 - auc_1: 0.9948 - val_loss: 1.2527 - val_auc_1: 0.7989
# Epoch 92/200
#  - 4s - loss: 0.1085 - auc_1: 0.9939 - val_loss: 1.0383 - val_auc_1: 0.7842
# Epoch 93/200
#  - 4s - loss: 0.1442 - auc_1: 0.9886 - val_loss: 0.9937 - val_auc_1: 0.7882
# Epoch 94/200
#  - 4s - loss: 0.1352 - auc_1: 0.9911 - val_loss: 1.7240 - val_auc_1: 0.8051
# Epoch 95/200
#  - 5s - loss: 0.1381 - auc_1: 0.9883 - val_loss: 1.0844 - val_auc_1: 0.8062
# Epoch 96/200
#  - 4s - loss: 0.1008 - auc_1: 0.9945 - val_loss: 1.7153 - val_auc_1: 0.8012
# Epoch 97/200
#  - 5s - loss: 0.1080 - auc_1: 0.9924 - val_loss: 1.3798 - val_auc_1: 0.7931
# Epoch 98/200
#  - 4s - loss: 0.0913 - auc_1: 0.9968 - val_loss: 0.4813 - val_auc_1: 0.8124
# Epoch 99/200
#  - 4s - loss: 0.1027 - auc_1: 0.9941 - val_loss: 0.6257 - val_auc_1: 0.7942
# Epoch 100/200
#  - 5s - loss: 0.1030 - auc_1: 0.9934 - val_loss: 1.8729 - val_auc_1: 0.7992
# Epoch 101/200
#  - 5s - loss: 0.0964 - auc_1: 0.9947 - val_loss: 1.4431 - val_auc_1: 0.8029
# Epoch 102/200
#  - 4s - loss: 0.0804 - auc_1: 0.9963 - val_loss: 1.3555 - val_auc_1: 0.7873
# Epoch 103/200
#  - 4s - loss: 0.0756 - auc_1: 0.9973 - val_loss: 1.5229 - val_auc_1: 0.7955
# Epoch 104/200
#  - 5s - loss: 0.1007 - auc_1: 0.9930 - val_loss: 1.3761 - val_auc_1: 0.7817
# Epoch 105/200
#  - 5s - loss: 0.0969 - auc_1: 0.9944 - val_loss: 1.2750 - val_auc_1: 0.7883
# Epoch 106/200
#  - 4s - loss: 0.0884 - auc_1: 0.9946 - val_loss: 0.6202 - val_auc_1: 0.7966
# Epoch 107/200
#  - 5s - loss: 0.0834 - auc_1: 0.9965 - val_loss: 1.9411 - val_auc_1: 0.8030
# Epoch 108/200
#  - 5s - loss: 0.1193 - auc_1: 0.9910 - val_loss: 1.1466 - val_auc_1: 0.7936
# Epoch 109/200
#  - 5s - loss: 0.1132 - auc_1: 0.9920 - val_loss: 1.5970 - val_auc_1: 0.8010
# Epoch 110/200
#  - 5s - loss: 0.0648 - auc_1: 0.9984 - val_loss: 1.0988 - val_auc_1: 0.7936
# Epoch 111/200
#  - 5s - loss: 0.0535 - auc_1: 0.9989 - val_loss: 1.2753 - val_auc_1: 0.7975
# Epoch 112/200
#  - 4s - loss: 0.0461 - auc_1: 0.9994 - val_loss: 1.4388 - val_auc_1: 0.7981
# Epoch 113/200
#  - 4s - loss: 0.0610 - auc_1: 0.9979 - val_loss: 1.1001 - val_auc_1: 0.7999
# Epoch 114/200
#  - 5s - loss: 0.0622 - auc_1: 0.9983 - val_loss: 1.1257 - val_auc_1: 0.7930
# Epoch 115/200
#  - 5s - loss: 0.0560 - auc_1: 0.9985 - val_loss: 1.2355 - val_auc_1: 0.8014
# Epoch 116/200
#  - 5s - loss: 0.0451 - auc_1: 0.9994 - val_loss: 1.7740 - val_auc_1: 0.8052
# Epoch 117/200
#  - 5s - loss: 0.0423 - auc_1: 0.9992 - val_loss: 1.4430 - val_auc_1: 0.7995
# Epoch 118/200
#  - 5s - loss: 0.0864 - auc_1: 0.9943 - val_loss: 2.1498 - val_auc_1: 0.7868
# Epoch 119/200
#  - 4s - loss: 0.0762 - auc_1: 0.9967 - val_loss: 2.1371 - val_auc_1: 0.7829
# Epoch 120/200
#  - 5s - loss: 0.0482 - auc_1: 0.9989 - val_loss: 1.8492 - val_auc_1: 0.7858
# Epoch 121/200
#  - 5s - loss: 0.0551 - auc_1: 0.9987 - val_loss: 1.4465 - val_auc_1: 0.7936
# Epoch 122/200
#  - 5s - loss: 0.0572 - auc_1: 0.9985 - val_loss: 2.6351 - val_auc_1: 0.7907
# Epoch 123/200
#  - 5s - loss: 0.0741 - auc_1: 0.9970 - val_loss: 1.3268 - val_auc_1: 0.7546
# Epoch 124/200
#  - 5s - loss: 0.0487 - auc_1: 0.9991 - val_loss: 2.0384 - val_auc_1: 0.7945
# Epoch 125/200
#  - 4s - loss: 0.0368 - auc_1: 0.9997 - val_loss: 1.2633 - val_auc_1: 0.7877
# Epoch 126/200
#  - 5s - loss: 0.0385 - auc_1: 0.9995 - val_loss: 1.5416 - val_auc_1: 0.7938
# Epoch 127/200
#  - 5s - loss: 0.0455 - auc_1: 0.9991 - val_loss: 1.8135 - val_auc_1: 0.7931
# Epoch 128/200
#  - 5s - loss: 0.0799 - auc_1: 0.9953 - val_loss: 1.0255 - val_auc_1: 0.7969
# Epoch 129/200
#  - 4s - loss: 0.0959 - auc_1: 0.9947 - val_loss: 1.0467 - val_auc_1: 0.7497
# Epoch 130/200
#  - 5s - loss: 0.0938 - auc_1: 0.9943 - val_loss: 1.7526 - val_auc_1: 0.7940
# Epoch 131/200
#  - 5s - loss: 0.0528 - auc_1: 0.9990 - val_loss: 1.5792 - val_auc_1: 0.7966
# Epoch 132/200
#  - 5s - loss: 0.0366 - auc_1: 0.9996 - val_loss: 0.6835 - val_auc_1: 0.7962
# Epoch 133/200
#  - 5s - loss: 0.0449 - auc_1: 0.9993 - val_loss: 2.4233 - val_auc_1: 0.7916
# Epoch 134/200
#  - 5s - loss: 0.0732 - auc_1: 0.9968 - val_loss: 1.4630 - val_auc_1: 0.7810
# Epoch 135/200
#  - 5s - loss: 0.0641 - auc_1: 0.9977 - val_loss: 0.8796 - val_auc_1: 0.7883
# Epoch 136/200
#  - 4s - loss: 0.0558 - auc_1: 0.9972 - val_loss: 1.4625 - val_auc_1: 0.7847
# Epoch 137/200
#  - 5s - loss: 0.0405 - auc_1: 0.9992 - val_loss: 1.3742 - val_auc_1: 0.7885
# Epoch 138/200
#  - 5s - loss: 0.0310 - auc_1: 0.9997 - val_loss: 1.9578 - val_auc_1: 0.7940
# Epoch 139/200
#  - 5s - loss: 0.0276 - auc_1: 0.9998 - val_loss: 2.0946 - val_auc_1: 0.7947
# Epoch 140/200
#  - 5s - loss: 0.0263 - auc_1: 0.9998 - val_loss: 1.3119 - val_auc_1: 0.7820
# Epoch 141/200
#  - 5s - loss: 0.0197 - auc_1: 1.0000 - val_loss: 1.0406 - val_auc_1: 0.7968
# Epoch 142/200
#  - 4s - loss: 0.0262 - auc_1: 0.9997 - val_loss: 1.6758 - val_auc_1: 0.7807
# Epoch 143/200
#  - 5s - loss: 0.0222 - auc_1: 0.9999 - val_loss: 1.0528 - val_auc_1: 0.7947
# Epoch 144/200
#  - 5s - loss: 0.0392 - auc_1: 0.9992 - val_loss: 2.0585 - val_auc_1: 0.7903
# Epoch 145/200
#  - 5s - loss: 0.0546 - auc_1: 0.9985 - val_loss: 0.8489 - val_auc_1: 0.7902
# Epoch 146/200
#  - 5s - loss: 0.0313 - auc_1: 0.9997 - val_loss: 2.2211 - val_auc_1: 0.7932
# Epoch 147/200
#  - 5s - loss: 0.0315 - auc_1: 0.9995 - val_loss: 1.5107 - val_auc_1: 0.7912
# Epoch 148/200
#  - 5s - loss: 0.0231 - auc_1: 0.9998 - val_loss: 1.3383 - val_auc_1: 0.7858
# Epoch 149/200
#  - 5s - loss: 0.0366 - auc_1: 0.9994 - val_loss: 2.5223 - val_auc_1: 0.7975
# Epoch 150/200
#  - 5s - loss: 0.0308 - auc_1: 0.9998 - val_loss: 1.3475 - val_auc_1: 0.7921
# Epoch 151/200
#  - 5s - loss: 0.0283 - auc_1: 0.9997 - val_loss: 0.9725 - val_auc_1: 0.7892
# Epoch 152/200
#  - 5s - loss: 0.0254 - auc_1: 0.9998 - val_loss: 0.4948 - val_auc_1: 0.7977
# Epoch 153/200
#  - 5s - loss: 0.1202 - auc_1: 0.9927 - val_loss: 2.4027 - val_auc_1: 0.7574
# Epoch 154/200
#  - 5s - loss: 0.1640 - auc_1: 0.9839 - val_loss: 2.0053 - val_auc_1: 0.7700
# Epoch 155/200
#  - 4s - loss: 0.0562 - auc_1: 0.9987 - val_loss: 1.0763 - val_auc_1: 0.7941
# Epoch 156/200
#  - 4s - loss: 0.0359 - auc_1: 0.9995 - val_loss: 1.4177 - val_auc_1: 0.7935
# Epoch 157/200
#  - 5s - loss: 0.0293 - auc_1: 1.0000 - val_loss: 0.7571 - val_auc_1: 0.8092
# Epoch 158/200
#  - 5s - loss: 0.0314 - auc_1: 0.9995 - val_loss: 1.6483 - val_auc_1: 0.7678
# Epoch 159/200
#  - 4s - loss: 0.0247 - auc_1: 0.9999 - val_loss: 1.5980 - val_auc_1: 0.7982
# Epoch 160/200
#  - 5s - loss: 0.0241 - auc_1: 0.9998 - val_loss: 1.6554 - val_auc_1: 0.7864
# Epoch 161/200
#  - 5s - loss: 0.0271 - auc_1: 0.9996 - val_loss: 1.5896 - val_auc_1: 0.7798
# Epoch 162/200
#  - 5s - loss: 0.0153 - auc_1: 1.0000 - val_loss: 2.9486 - val_auc_1: 0.7878
# Epoch 163/200
#  - 5s - loss: 0.0412 - auc_1: 0.9991 - val_loss: 1.8888 - val_auc_1: 0.7733
# Epoch 164/200
#  - 5s - loss: 0.0516 - auc_1: 0.9984 - val_loss: 0.8059 - val_auc_1: 0.7648
# Epoch 165/200
#  - 4s - loss: 0.0482 - auc_1: 0.9987 - val_loss: 2.4552 - val_auc_1: 0.7874
# Epoch 166/200
#  - 4s - loss: 0.0376 - auc_1: 0.9991 - val_loss: 1.7656 - val_auc_1: 0.7833
# Epoch 167/200
#  - 5s - loss: 0.0290 - auc_1: 0.9997 - val_loss: 1.9731 - val_auc_1: 0.7905
# Epoch 168/200
#  - 5s - loss: 0.0328 - auc_1: 0.9994 - val_loss: 1.1363 - val_auc_1: 0.7881
# Epoch 169/200
#  - 4s - loss: 0.0201 - auc_1: 0.9999 - val_loss: 0.9691 - val_auc_1: 0.7847
# Epoch 170/200
#  - 4s - loss: 0.0136 - auc_1: 1.0000 - val_loss: 0.9160 - val_auc_1: 0.7734
# Epoch 171/200
#  - 4s - loss: 0.0166 - auc_1: 0.9998 - val_loss: 1.3053 - val_auc_1: 0.7921
# Epoch 172/200
#  - 4s - loss: 0.0164 - auc_1: 0.9999 - val_loss: 1.2980 - val_auc_1: 0.7785
# Epoch 173/200
#  - 4s - loss: 0.0135 - auc_1: 1.0000 - val_loss: 1.1820 - val_auc_1: 0.7972
# Epoch 174/200
#  - 4s - loss: 0.0182 - auc_1: 0.9999 - val_loss: 2.2864 - val_auc_1: 0.7820
# Epoch 175/200
#  - 4s - loss: 0.0146 - auc_1: 0.9999 - val_loss: 1.2976 - val_auc_1: 0.7881
# Epoch 176/200
#  - 5s - loss: 0.0089 - auc_1: 1.0000 - val_loss: 1.0294 - val_auc_1: 0.7832
# Epoch 177/200
#  - 4s - loss: 0.0121 - auc_1: 1.0000 - val_loss: 1.5176 - val_auc_1: 0.7866
# Epoch 178/200
#  - 5s - loss: 0.0228 - auc_1: 0.9997 - val_loss: 1.0921 - val_auc_1: 0.7889
# Epoch 179/200
#  - 5s - loss: 0.0184 - auc_1: 0.9999 - val_loss: 1.0782 - val_auc_1: 0.7690
# Epoch 180/200
#  - 4s - loss: 0.0556 - auc_1: 0.9968 - val_loss: 1.7544 - val_auc_1: 0.8084
# Epoch 181/200
#  - 5s - loss: 0.0370 - auc_1: 0.9995 - val_loss: 1.1596 - val_auc_1: 0.7805
# Epoch 182/200
#  - 5s - loss: 0.0304 - auc_1: 0.9995 - val_loss: 1.2017 - val_auc_1: 0.7975
# Epoch 183/200
#  - 4s - loss: 0.0257 - auc_1: 0.9998 - val_loss: 0.8447 - val_auc_1: 0.8014
# Epoch 184/200
#  - 4s - loss: 0.0162 - auc_1: 0.9999 - val_loss: 1.6805 - val_auc_1: 0.8035
# Epoch 185/200
#  - 4s - loss: 0.0082 - auc_1: 1.0000 - val_loss: 1.6064 - val_auc_1: 0.7918
# Epoch 186/200
#  - 4s - loss: 0.0092 - auc_1: 1.0000 - val_loss: 1.3191 - val_auc_1: 0.8054
# Epoch 187/200
#  - 4s - loss: 0.0201 - auc_1: 0.9999 - val_loss: 2.1746 - val_auc_1: 0.8014
# Epoch 188/200
#  - 4s - loss: 0.0151 - auc_1: 0.9999 - val_loss: 2.1713 - val_auc_1: 0.8074
# Epoch 189/200
#  - 4s - loss: 0.0197 - auc_1: 0.9999 - val_loss: 1.7490 - val_auc_1: 0.7988
# Epoch 190/200
#  - 4s - loss: 0.0144 - auc_1: 1.0000 - val_loss: 1.5732 - val_auc_1: 0.7905
# Epoch 191/200
#  - 4s - loss: 0.0141 - auc_1: 1.0000 - val_loss: 0.7453 - val_auc_1: 0.7776
# Epoch 192/200
#  - 4s - loss: 0.0416 - auc_1: 0.9992 - val_loss: 2.6469 - val_auc_1: 0.7840
# Epoch 193/200
#  - 4s - loss: 0.1259 - auc_1: 0.9915 - val_loss: 1.0787 - val_auc_1: 0.7858
# Epoch 194/200
#  - 4s - loss: 0.0545 - auc_1: 0.9982 - val_loss: 1.3270 - val_auc_1: 0.7877
# Epoch 195/200
#  - 4s - loss: 0.0645 - auc_1: 0.9974 - val_loss: 1.7647 - val_auc_1: 0.8064
# Epoch 196/200
#  - 4s - loss: 0.0383 - auc_1: 0.9991 - val_loss: 2.0414 - val_auc_1: 0.8121
# Epoch 197/200
#  - 4s - loss: 0.0241 - auc_1: 0.9997 - val_loss: 1.0906 - val_auc_1: 0.7968
# Epoch 198/200
#  - 4s - loss: 0.0245 - auc_1: 0.9996 - val_loss: 1.3979 - val_auc_1: 0.7866
# Epoch 199/200
#  - 4s - loss: 0.0337 - auc_1: 0.9982 - val_loss: 1.0266 - val_auc_1: 0.7702
# Epoch 200/200
#  - 4s - loss: 0.0336 - auc_1: 0.9981 - val_loss: 0.6405 - val_auc_1: 0.7842

# %% [markdown]
# **Create a function that outputs metrics and charts**

# %%
def create_charts(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator.classes
    Y_pred = cnn.predict_generator(test_generator, steps = len(test_generator))
    y_pred = (Y_pred > 0.5).T[0]
    y_pred_prob = Y_pred.T[0]
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts(cnn, cnn_model)
# Out:
# [Summary Statistics]
# Accuracy = 73.68% | Precision = 67.31% | Recall = 86.42% | Specificity = 62.22% | F1 Score = 75.68%
